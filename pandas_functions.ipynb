# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
df = pd.read_csv("dunkin_stores.csv")
# Out:
#      <input type="file" id="files-b1e19e42-95fc-4228-9bc1-25fc5734cf23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1e19e42-95fc-4228-9bc1-25fc5734cf23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape #the first value gives us number of rows and the second value gives us number of columns
# Out:
# (9248, 22)

# %% [markdown]
# if you see object as data type of a column typically that means it's a string

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9248 entries, 0 to 9247
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   row_id              9248 non-null   int64
#  1   address_line_1      9248 non-null   object
#  2   address_line_2      1763 non-null   object
#  3   city                9248 non-null   object
#  4   state               9248 non-null   object
#  5   zip                 9248 non-null   int64
#  6   phone               9126 non-null   object
#  7   mon_hrs             9248 non-null   object
#  8   tue_hrs             9248 non-null   object
#  9   wed_hrs             9248 non-null   object
#  10  thu_hrs             9248 non-null   object
#  11  fri_hrs             9248 non-null   object
#  12  sat_hrs             9248 non-null   object
#  13  sun_hrs             9248 non-null   object
#  14  drive-thru          9248 non-null   bool
# ...

# %%
df.head()
# Out:
#    row_id        address_line_1 address_line_2         city state    zip  \
# 0       0         1114 1st St N      Suite 200    Alabaster    AL  35007
# 1       1   8171 US Highway 431            NaN  Albertville    AL  35950
# 2       2  1700 US Highway 72 E            NaN       Athens    AL  35611
# 3       3      171 N College St            NaN       Auburn    AL  36830
# 4       4     2049 S College St            NaN       Auburn    AL  36832
#
#             phone            mon_hrs            tue_hrs            wed_hrs  \
# 0  (205) 624-4880  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM
# 1  (256) 869-6075  5:00 AM - 9:00 PM  5:00 AM - 9:00 PM  5:00 AM - 9:00 PM
# 2  (256) 960-9302  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM
# 3  (334) 707-8552  6:00 AM - 3:00 PM  6:00 AM - 3:00 PM  6:00 AM - 3:00 PM
# 4  (334) 501-2233  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM
#
#    ...             sat_hrs            sun_hrs drive-thru mobile-order  \
# ...

# %%
df.tail()
# Out:
#       row_id             address_line_1 address_line_2              city  \
# 9243    9243     106 W Silver Spring Dr          Ste A     Whitefish Bay
# 9244    9244  2415 Wisconsin Dells Pkwy            NaN   Wisconsin Dells
# 9245    9245             69 Commerce St            NaN   Wisconsin Dells
# 9246    9246              2121 8th St S            NaN  Wisconsin Rapids
# 9247    9247            6305 Missile Dr            NaN     FE Warren AFB
#
#      state    zip           phone            mon_hrs            tue_hrs  \
# 9243    WI  53217  (414) 284-7608  6:00 AM - 6:00 PM  6:00 AM - 6:00 PM
# 9244    WI  53965  (608) 253-5353  5:30 AM - 8:00 PM  5:30 AM - 8:00 PM
# 9245    WI  53965  (608) 350-9029  5:30 AM - 8:00 PM  5:30 AM - 8:00 PM
# 9246    WI  54494  (715) 204-5260  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM
# 9247    WY  82005  (307) 637-2818  6:00 AM - 5:00 PM  6:00 AM - 5:00 PM
#
#                 wed_hrs  ...            sat_hrs            sun_hrs drive-thru  \
# ...

# %%
df.columns
# Out:
# Index(['row_id', 'address_line_1', 'address_line_2', 'city', 'state', 'zip',
#        'phone', 'mon_hrs', 'tue_hrs', 'wed_hrs', 'thu_hrs', 'fri_hrs',
#        'sat_hrs', 'sun_hrs', 'drive-thru', 'mobile-order', 'dunkin-card',
#        'kcup', 'curbside-pickup', 'has-baskin-robbins', 'loc_lat', 'loc_long'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9248, step=1)

# %%
df.values #you can get the body of your data frames by attribute values this gives you back a numpy array
# Out:
# array([[0, '1114 1st St N', 'Suite 200', ..., False, nan, nan],
#        [1, '8171 US Highway 431', nan, ..., True, nan, nan],
#        [2, '1700 US Highway 72 E', nan, ..., False, 34.78169848062834,
#         -86.93452385029505],
#        ...,
#        [9245, '69 Commerce St', nan, ..., False, nan, nan],
#        [9246, '2121 8th St S', nan, ..., False, 44.37593438356343,
#         -89.81689750208463],
#        [9247, '6305 Missile Dr', nan, ..., True, nan, nan]], dtype=object)

# %%
df.dtypes #so if you just care about the columns and their data types you can use the dtypes attribute
# Out:
# row_id                  int64
# address_line_1         object
# address_line_2         object
# city                   object
# state                  object
# zip                     int64
# phone                  object
# mon_hrs                object
# tue_hrs                object
# wed_hrs                object
# thu_hrs                object
# fri_hrs                object
# sat_hrs                object
# sun_hrs                object
# drive-thru               bool
# mobile-order             bool
# dunkin-card              bool
# kcup                     bool
# curbside-pickup          bool
# has-baskin-robbins       bool
# loc_lat               float64
# loc_long              float64
# dtype: object

# %%
df.nunique()
# Out:
# row_id                9248
# address_line_1        9144
# address_line_2         970
# city                  3126
# state                   45
# zip                   5062
# phone                 8989
# mon_hrs                235
# tue_hrs                230
# wed_hrs                227
# thu_hrs                230
# fri_hrs                231
# sat_hrs                229
# sun_hrs                229
# drive-thru               2
# mobile-order             2
# dunkin-card              2
# kcup                     2
# curbside-pickup          2
# has-baskin-robbins       2
# loc_lat               6095
# loc_long              6095
# dtype: int64

# %% [markdown]
# So these were some methods and attributes you'd want to apply to see everything loaded up correctly.

# %%
city = df['city']

# %%
city
# Out:
# 0              Alabaster
# 1            Albertville
# 2                 Athens
# 3                 Auburn
# 4                 Auburn
#               ...
# 9243       Whitefish Bay
# 9244     Wisconsin Dells
# 9245     Wisconsin Dells
# 9246    Wisconsin Rapids
# 9247       FE Warren AFB
# Name: city, Length: 9248, dtype: object

# %%
type(city)
# Out:
# pandas.core.series.Series

# %% [markdown]
# If we look at the type of city now it's a series not a data frame , so in pandas data frame each column is a pandas series and a series is essentially an extension of a numpy array

# %%
city = df[['city']] #if we want to get a data frame version of our city data set back we have to pass in a python list so that's why we have two square
#brackets , outer square bracket specifies that we are doing subsetting and the inner one specifies that we want output as a data set
city
# Out:
#                   city
# 0            Alabaster
# 1          Albertville
# 2               Athens
# 3               Auburn
# 4               Auburn
# ...                ...
# 9243     Whitefish Bay
# 9244   Wisconsin Dells
# 9245   Wisconsin Dells
# 9246  Wisconsin Rapids
# 9247     FE Warren AFB
#
# [9248 rows x 1 columns]

# %%
#dropping columns in data set
#so by default it drops things from the rows so we have to give another parameter for dropping columns which is 'axis'
#so axis is either 0 for a row or 1 for column but in newer version of python you can actually pass string'index' or 'columns' in axis parameter
#which makes the code a little bit more readable

df.drop(['loc_lat','loc_long'] , axis='columns')
# Out:
#       row_id             address_line_1 address_line_2              city  \
# 0          0              1114 1st St N      Suite 200         Alabaster
# 1          1        8171 US Highway 431            NaN       Albertville
# 2          2       1700 US Highway 72 E            NaN            Athens
# 3          3           171 N College St            NaN            Auburn
# 4          4          2049 S College St            NaN            Auburn
# ...      ...                        ...            ...               ...
# 9243    9243     106 W Silver Spring Dr          Ste A     Whitefish Bay
# 9244    9244  2415 Wisconsin Dells Pkwy            NaN   Wisconsin Dells
# 9245    9245             69 Commerce St            NaN   Wisconsin Dells
# 9246    9246              2121 8th St S            NaN  Wisconsin Rapids
# 9247    9247            6305 Missile Dr            NaN     FE Warren AFB
#
#      state    zip           phone            mon_hrs            tue_hrs  \
# ...

# %%
df.head(3)
# Out:
#    row_id        address_line_1 address_line_2         city state    zip  \
# 0       0         1114 1st St N      Suite 200    Alabaster    AL  35007
# 1       1   8171 US Highway 431            NaN  Albertville    AL  35950
# 2       2  1700 US Highway 72 E            NaN       Athens    AL  35611
#
#             phone            mon_hrs            tue_hrs            wed_hrs  \
# 0  (205) 624-4880  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM
# 1  (256) 869-6075  5:00 AM - 9:00 PM  5:00 AM - 9:00 PM  5:00 AM - 9:00 PM
# 2  (256) 960-9302  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM
#
#    ...             sat_hrs            sun_hrs drive-thru mobile-order  \
# 0  ...   6:00 AM - 8:00 PM  6:00 AM - 8:00 PM       True        False
# 1  ...  5:00 AM - 10:00 PM  5:00 AM - 9:00 PM       True         True
# 2  ...   5:00 AM - 8:00 PM  5:00 AM - 8:00 PM       True         True
#
#    dunkin-card   kcup  curbside-pickup  has-baskin-robbins    loc_lat  \
# ...

# %%
df_new = df.drop(['loc_lat','loc_long'] , axis='columns')
df_new.head()
# Out:
#    row_id        address_line_1 address_line_2         city state    zip  \
# 0       0         1114 1st St N      Suite 200    Alabaster    AL  35007
# 1       1   8171 US Highway 431            NaN  Albertville    AL  35950
# 2       2  1700 US Highway 72 E            NaN       Athens    AL  35611
# 3       3      171 N College St            NaN       Auburn    AL  36830
# 4       4     2049 S College St            NaN       Auburn    AL  36832
#
#             phone            mon_hrs            tue_hrs            wed_hrs  \
# 0  (205) 624-4880  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM
# 1  (256) 869-6075  5:00 AM - 9:00 PM  5:00 AM - 9:00 PM  5:00 AM - 9:00 PM
# 2  (256) 960-9302  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM
# 3  (334) 707-8552  6:00 AM - 3:00 PM  6:00 AM - 3:00 PM  6:00 AM - 3:00 PM
# 4  (334) 501-2233  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM
#
#              thu_hrs             fri_hrs             sat_hrs  \
# ...

# %% [markdown]
# So as you can see that the dropped values aren't saved or hasn't changed our original data frame but instead it returned a copy or a view. In order to that we can use another parameter (inplace) which modifies the original data frame, or you have to reassign it for example
#
#  df_dropped = df.drop(['loc_lat' , 'loc_long'] , axis='columns')
# it actually saves the dropped values

# %%
#subsetting rows
df.loc[0]
#we'll get the first row back as a series object
# Out:
# row_id                                0
# address_line_1            1114 1st St N
# address_line_2                Suite 200
# city                          Alabaster
# state                                AL
# zip                               35007
# phone                    (205) 624-4880
# mon_hrs               5:00 AM - 8:00 PM
# tue_hrs               5:00 AM - 8:00 PM
# wed_hrs               5:00 AM - 8:00 PM
# thu_hrs               5:00 AM - 8:00 PM
# fri_hrs               5:00 AM - 8:00 PM
# sat_hrs               6:00 AM - 8:00 PM
# sun_hrs               6:00 AM - 8:00 PM
# drive-thru                         True
# mobile-order                      False
# dunkin-card                        True
# kcup                               True
# curbside-pickup                   False
# has-baskin-robbins                False
# loc_lat                             NaN
# loc_long                            NaN
# Name: 0, dtype: object

# %%
df.loc[[0,1]]#this will get the first and second row back as a df
# Out:
#    row_id       address_line_1 address_line_2         city state    zip  \
# 0       0        1114 1st St N      Suite 200    Alabaster    AL  35007
# 1       1  8171 US Highway 431            NaN  Albertville    AL  35950
#
#             phone            mon_hrs            tue_hrs            wed_hrs  \
# 0  (205) 624-4880  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM
# 1  (256) 869-6075  5:00 AM - 9:00 PM  5:00 AM - 9:00 PM  5:00 AM - 9:00 PM
#
#    ...             sat_hrs            sun_hrs drive-thru mobile-order  \
# 0  ...   6:00 AM - 8:00 PM  6:00 AM - 8:00 PM       True        False
# 1  ...  5:00 AM - 10:00 PM  5:00 AM - 9:00 PM       True         True
#
#    dunkin-card   kcup  curbside-pickup  has-baskin-robbins  loc_lat  loc_long
# 0         True   True            False               False      NaN       NaN
# 1         True  False            False                True      NaN       NaN
#
# [2 rows x 22 columns]

# %% [markdown]
# So the loc isn't really looking for the first and second row in our data set but it's essentially doing like a string match to the index , like gives you the row that has 0 or 1 as its index label

# %%
#so for example in python if given a list and you give it a negative number it starts counting backwards but here with loc you can't do it
df.loc[-1]
#we'll get an error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     390                 try:
# --> 391                     return self._range.index(new_key)
#     392                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-51d0dcfe9c01> in <cell line: 2>()
#       1 #so for example in python if given a list and you give it a negative number it starts counting backwards but here with loc you can't do it
# ----> 2 df.loc[-1]
#       3 #we'll get an error
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
# ...

# %% [markdown]
# So pandas gives us another way to subset rows as well which is iloc and this actually uses the index.

# %%
df.iloc[[0,1,-1]]
#now here we'll get the value back of first second and the last row.
# Out:
#       row_id       address_line_1 address_line_2           city state    zip  \
# 0          0        1114 1st St N      Suite 200      Alabaster    AL  35007
# 1          1  8171 US Highway 431            NaN    Albertville    AL  35950
# 9247    9247      6305 Missile Dr            NaN  FE Warren AFB    WY  82005
#
#                phone            mon_hrs            tue_hrs            wed_hrs  \
# 0     (205) 624-4880  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM
# 1     (256) 869-6075  5:00 AM - 9:00 PM  5:00 AM - 9:00 PM  5:00 AM - 9:00 PM
# 9247  (307) 637-2818  6:00 AM - 5:00 PM  6:00 AM - 5:00 PM  6:00 AM - 5:00 PM
#
#       ...             sat_hrs            sun_hrs drive-thru mobile-order  \
# 0     ...   6:00 AM - 8:00 PM  6:00 AM - 8:00 PM       True        False
# 1     ...  5:00 AM - 10:00 PM  5:00 AM - 9:00 PM       True         True
# 9247  ...   8:00 AM - 3:00 PM  8:00 AM - 3:00 PM       True         True
#
# ...

# %%
#subsetting rows and columns together

subset = df.loc[:,['address_line_1','city']] #here leaving the first parameter empty means i want to have all rows of those sepcific columns
subset.head()
# Out:
#          address_line_1         city
# 0         1114 1st St N    Alabaster
# 1   8171 US Highway 431  Albertville
# 2  1700 US Highway 72 E       Athens
# 3      171 N College St       Auburn
# 4     2049 S College St       Auburn

# %%
subset = df.iloc[:,['address_line_1','city']] #so if we do the same thing using iloc it will give an error
#since address_line_1 and city isn't a valid positional argument iloc uses index or position
subset.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-5da3dcb6890f> in <cell line: 1>()
# ----> 1 subset = df.iloc[:,['address_line_1','city']] #so if we do the same thing using iloc it will give an error
#       2 #since address_line_1 and city isn't a valid positional argument iloc uses index or position
#       3 subset.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1561     def _getitem_tuple(self, tup: tuple):
#    1562
# ...

# %%
#but instead we'll give:
subset = df.iloc[:,[1,3]]
subset.head()
# Out:
#          address_line_1         city
# 0         1114 1st St N    Alabaster
# 1   8171 US Highway 431  Albertville
# 2  1700 US Highway 72 E       Athens
# 3      171 N College St       Auburn
# 4     2049 S College St       Auburn

# %%
#So if I want to select the state column and then I'll just filter the data set in such a way that the state column is
#just the ones which is equal of AL state
df.loc[df['state'] == 'AL']
# Out:
#     row_id            address_line_1 address_line_2            city state  \
# 0        0             1114 1st St N      Suite 200       Alabaster    AL
# 1        1       8171 US Highway 431            NaN     Albertville    AL
# 2        2      1700 US Highway 72 E            NaN          Athens    AL
# 3        3          171 N College St            NaN          Auburn    AL
# 4        4         2049 S College St            NaN          Auburn    AL
# 5        5    2178 Eastern Valley Rd            NaN        Bessemer    AL
# 6        6          1820 Gadsden Hwy        Ste 100      Birmingham    AL
# 7        7            2109 6th Ave S            NaN      Birmingham    AL
# 8        8            300 Commons Dr            NaN      Birmingham    AL
# 9        9       400 Cahaba Park Cir        Suite 1      Birmingham    AL
# 10      10        3201 Buttermilk Rd            NaN      Cottondale    AL
# 11      11        1600 County Rd 437            NaN         Cullman    AL
# ...

# %%
df.loc[(df['state'] == "AL") & (df['city'] == 'Auburn')]
# Out:
#    row_id     address_line_1 address_line_2    city state    zip  \
# 3       3   171 N College St            NaN  Auburn    AL  36830
# 4       4  2049 S College St            NaN  Auburn    AL  36832
#
#             phone            mon_hrs            tue_hrs            wed_hrs  \
# 3  (334) 707-8552  6:00 AM - 3:00 PM  6:00 AM - 3:00 PM  6:00 AM - 3:00 PM
# 4  (334) 501-2233  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM  5:00 AM - 8:00 PM
#
#    ...            sat_hrs            sun_hrs drive-thru mobile-order  \
# 3  ...  6:00 AM - 3:00 PM  6:00 AM - 3:00 PM      False        False
# 4  ...  5:00 AM - 8:00 PM  6:00 AM - 8:00 PM       True         True
#
#    dunkin-card  kcup  curbside-pickup  has-baskin-robbins    loc_lat  \
# 3         True  True            False               False  32.608800
# 4         True  True            False               False  32.567323
#
#     loc_long
# 3 -85.481849
# 4 -85.501589
#
# [2 rows x 22 columns]

# %%
df_long = pd.melt(df,
                  id_vars=['city', 'state' , 'address_line_1'])
df_long.tail()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
def get_val(key_to_find):
    for key, val in states.items():
        if key_to_find == key:
            return val
    return 'Key does not exist'

store_state = df.groupby('state').count()
store_state['state_name'] = [get_val(state_abrv) for state_abrv in store_state.index]

fig = px.choropleth(store_state,
                    locations = store_state.index,
                    color = 'row_id',
                    color_continuous_scale = 'oranges',
                    hover_name = store_state.state_name,
                    locationmode = 'USA-states',
                    labels = {'row_id': 'Number of Stores'}
                    )

fig.update_layout(title_text = "Count of Dunkin' stores per state",
                  geo_scope = 'usa')

fig.show()

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
df = pd.read_csv("titanic.csv")
# Out:
#      <input type="file" id="files-0c935763-81d3-4c74-8cdf-a19110edc613" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c935763-81d3-4c74-8cdf-a19110edc613">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic.csv to titanic.csv

# %%
len(df)
# Out:
# 1310

# %%
df.shape
# Out:
# (1310, 14)

# %%
df.iloc[:10, 5:10]
# Out:
#    sibsp  parch    ticket      fare    cabin
# 0    0.0    0.0     24160  211.3375       B5
# 1    1.0    2.0    113781  151.5500  C22 C26
# 2    1.0    2.0    113781  151.5500  C22 C26
# 3    1.0    2.0    113781  151.5500  C22 C26
# 4    1.0    2.0    113781  151.5500  C22 C26
# 5    0.0    0.0     19952   26.5500      E12
# 6    1.0    0.0     13502   77.9583       D7
# 7    0.0    0.0    112050    0.0000      A36
# 8    2.0    0.0     11769   51.4792     C101
# 9    0.0    0.0  PC 17609   49.5042      NaN

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df.iloc[[0,1,-1],0:6]
# Out:
#       pclass  survived                            name     sex      age  sibsp
# 0        1.0       1.0   Allen, Miss. Elisabeth Walton  female  29.0000    0.0
# 1        1.0       1.0  Allison, Master. Hudson Trevor    male   0.9167    1.0
# 1309     NaN       NaN                             NaN     NaN      NaN    NaN

# %%
df.iloc[:,1:3]
# Out:
#       survived                                             name
# 0          1.0                    Allen, Miss. Elisabeth Walton
# 1          1.0                   Allison, Master. Hudson Trevor
# 2          0.0                     Allison, Miss. Helen Loraine
# 3          0.0             Allison, Mr. Hudson Joshua Creighton
# 4          0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...        ...                                              ...
# 1305       0.0                            Zabour, Miss. Thamine
# 1306       0.0                        Zakarian, Mr. Mapriededer
# 1307       0.0                              Zakarian, Mr. Ortin
# 1308       0.0                               Zimmerman, Mr. Leo
# 1309       NaN                                              NaN
#
# [1310 rows x 2 columns]

# %%
df.loc[[0]]
# Out:
#    pclass  survived                           name     sex   age  sibsp  \
# 0     1.0       1.0  Allen, Miss. Elisabeth Walton  female  29.0    0.0
#
#    parch ticket      fare cabin embarked boat  body     home.dest
# 0    0.0  24160  211.3375    B5        S    2   NaN  St Louis, MO

# %%
df.dtypes
# Out:
# pclass       float64
# survived     float64
# name          object
# sex           object
# age          float64
# sibsp        float64
# parch        float64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
df.select_dtypes(include= 'object')
# Out:
#                                                  name     sex  ticket  \
# 0                       Allen, Miss. Elisabeth Walton  female   24160
# 1                      Allison, Master. Hudson Trevor    male  113781
# 2                        Allison, Miss. Helen Loraine  female  113781
# 3                Allison, Mr. Hudson Joshua Creighton    male  113781
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  113781
# ...                                               ...     ...     ...
# 1305                            Zabour, Miss. Thamine  female    2665
# 1306                        Zakarian, Mr. Mapriededer    male    2656
# 1307                              Zakarian, Mr. Ortin    male    2670
# 1308                               Zimmerman, Mr. Leo    male  315082
# 1309                                              NaN     NaN     NaN
#
#         cabin embarked boat                        home.dest
# 0          B5        S    2                     St Louis, MO
# ...

# %%
import numpy as np

# %%
#df.insert
#As the name of the function suggests, it inserts a column in the specified position.
# To demonstrate that I will first create an array of random numbers that have the length of our DataFrame:

random_col = np.random.randint(100, size=len(df))
#I will insert this array as a column in the DataFrame df at column 3 position. Remember, the column index starts from zero.
df.insert(3, 'random_col', random_col)
df.head()
# Out:
#    pclass  survived                                             name  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1     1.0       1.0                   Allison, Master. Hudson Trevor
# 2     1.0       0.0                     Allison, Miss. Helen Loraine
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#    random_col     sex      age  sibsp  parch  ticket      fare    cabin  \
# 0          89  female  29.0000    0.0    0.0   24160  211.3375       B5
# 1          94    male   0.9167    1.0    2.0  113781  151.5500  C22 C26
# 2          24  female   2.0000    1.0    2.0  113781  151.5500  C22 C26
# 3          28    male  30.0000    1.0    2.0  113781  151.5500  C22 C26
# 4          99  female  25.0000    1.0    2.0  113781  151.5500  C22 C26
#
#   embarked boat   body                        home.dest
# 0        S    2    NaN                     St Louis, MO
# ...

# %%
df['random_col'].where(df['random_col'] > 50)
# Out:
# 0       89.0
# 1       94.0
# 2        NaN
# 3        NaN
# 4       99.0
#         ...
# 1305    88.0
# 1306    65.0
# 1307     NaN
# 1308    89.0
# 1309     NaN
# Name: random_col, Length: 1310, dtype: float64

# %%
# Look, where the values do not meet the condition that means the value is not greater than 50, returns NaN.
#  We can replace NaN with 0 or any other value using this syntax:

df['random_col'].where(df['random_col'] > 50, 0)
# Out:
# 0       89
# 1       94
# 2        0
# 3        0
# 4       99
#         ..
# 1305    88
# 1306    65
# 1307     0
# 1308    89
# 1309     0
# Name: random_col, Length: 1310, dtype: int64

# %%
df.sex.unique()
# Out:
# array(['female', 'male', nan], dtype=object)

# %%
df.sex.nunique(dropna=False)
# Out:
# 3

# %%
df.nunique()

# %%
df['rank_calc'] = df["fare"].rank()
df.head()
# Out:
#    pclass  survived                                             name  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1     1.0       1.0                   Allison, Master. Hudson Trevor
# 2     1.0       0.0                     Allison, Miss. Helen Loraine
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#    random_col     sex      age  sibsp  parch  ticket      fare    cabin  \
# 0          89  female  29.0000    0.0    0.0   24160  211.3375       B5
# 1          94    male   0.9167    1.0    2.0  113781  151.5500  C22 C26
# 2          24  female   2.0000    1.0    2.0  113781  151.5500  C22 C26
# 3          28    male  30.0000    1.0    2.0  113781  151.5500  C22 C26
# 4          99  female  25.0000    1.0    2.0  113781  151.5500  C22 C26
#
#   embarked boat   body                        home.dest  rank_calc
# ...
